# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("SebastianSchramm/UniNER-7B-all-GPTQ-4bit-128g-actorder_True")
model = AutoModelForCausalLM.from_pretrained("SebastianSchramm/UniNER-7B-all-GPTQ-4bit-128g-actorder_True")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Some weights of the model checkpoint at SebastianSchramm/UniNER-7B-all-GPTQ-4bit-128g-actorder_True were not used when initializing LlamaForCausalLM: ['model.layers.0.self_attn.o_proj.scales', 'model.layers.15.self_attn.v_proj.bias', 'model.layers.31.mlp.down_proj.scales', 'model.layers.29.mlp.gate_proj.scales', 'model.layers.21.mlp.down_proj.bias', 'model.layers.21.self_attn.o_proj.g_idx', 'model.layers.25.mlp.up_proj.bias', 'model.layers.1.self_attn.o_proj.g_idx', 'model.layers.22.self_attn.v_proj.qzeros', 'model.layers.12.self_attn.q_proj.scales', 'model.layers.23.mlp.down_proj.g_idx', 'model.layers.28.self_attn.q_proj.qzeros', 'model.layers.15.self_attn.k_proj.g_idx', 'model.layers.29.self_attn.q_proj.scales', 'model.layers.5.mlp.down_proj.g_idx', 'model.layers.12.mlp.up_proj.scales', 'model.layers.18.self_attn.o_proj.scales', 'model.layers.23.mlp.up_proj.qzeros', 'model.layers.6.self_attn.k_proj.scales', 'model.layers.12.mlp.down_proj.scales', 'model.layers.23.self_attn.v_proj.bias', 'model.layers.23.self_attn.q_proj.g_idx', 'model.layers.18.self_attn.v_proj.bias', 'model.layers.21.mlp.up_proj.qweight', 'model.layers.14.mlp.up_proj.g_idx', 'model.layers.8.self_attn.o_proj.qweight', 'model.layers.19.mlp.up_proj.scales', 'model.layers.23.self_attn.k_proj.qzeros', 'model.layers.21.mlp.up_proj.qzeros', 'model.layers.20.mlp.up_proj.bias', 'model.layers.2.mlp.up_proj.qweight', 'model.layers.16.mlp.gate_proj.qzeros', 'model.layers.6.mlp.up_proj.scales', 'model.layers.12.self_attn.o_proj.scales', 'model.layers.16.self_attn.q_proj.g_idx', 'model.layers.9.self_attn.v_proj.bias', 'model.layers.20.self_attn.v_proj.qweight', 'model.layers.25.self_attn.v_proj.bias', 'model.layers.27.mlp.up_proj.g_idx', 'model.layers.15.self_attn.q_proj.qzeros', 'model.layers.17.mlp.gate_proj.scales', 'model.layers.31.self_attn.k_proj.qzeros', 'model.layers.12.mlp.down_proj.g_idx', 'model.layers.19.self_attn.o_proj.bias', 'model.layers.22.mlp.up_proj.qweight', 'model.layers.26.self_attn.o_proj.bias', 'model.layers.20.self_attn.q_proj.qweight', 'model.layers.6.self_attn.k_proj.qweight', 'model.layers.13.self_attn.k_proj.bias', 'model.layers.27.mlp.up_proj.qweight', 'model.layers.23.self_attn.o_proj.qweight', 'model.layers.21.mlp.gate_proj.g_idx', 'model.layers.27.mlp.down_proj.g_idx', 'model.layers.9.self_attn.q_proj.g_idx', 'model.layers.6.self_attn.o_proj.scales', 'model.layers.11.self_attn.q_proj.bias', 'model.layers.12.self_attn.v_proj.scales', 'model.layers.20.self_attn.o_proj.scales', 'model.layers.21.self_attn.o_proj.qzeros', 'model.layers.3.mlp.up_proj.scales', 'model.layers.5.self_attn.k_proj.bias', 'model.layers.9.self_attn.q_proj.qweight', 'model.layers.23.mlp.gate_proj.scales', 'model.layers.16.mlp.gate_proj.bias', 'model.layers.9.self_attn.o_proj.scales', 'model.layers.22.mlp.down_proj.g_idx', 'model.layers.14.mlp.down_proj.qzeros', 'model.layers.22.self_attn.k_proj.g_idx', 'model.layers.14.self_attn.o_proj.qweight', 'model.layers.9.mlp.up_proj.bias', 'model.layers.18.mlp.gate_proj.scales', 'model.layers.9.mlp.up_proj.qzeros', 'model.layers.1.self_attn.q_proj.bias', 'model.layers.2.self_attn.o_proj.g_idx', 'model.layers.2.self_attn.v_proj.bias', 'model.layers.24.self_attn.o_proj.bias', 'model.layers.20.self_attn.o_proj.qzeros', 'model.layers.8.self_attn.v_proj.qzeros', 'model.layers.9.self_attn.q_proj.bias', 'model.layers.26.self_attn.q_proj.qzeros', 'model.layers.7.mlp.up_proj.bias', 'model.layers.13.self_attn.o_proj.bias', 'model.layers.16.self_attn.v_proj.qzeros', 'model.layers.24.mlp.down_proj.bias', 'model.layers.2.mlp.gate_proj.g_idx', 'model.layers.24.self_attn.o_proj.scales', 'model.layers.30.mlp.down_proj.g_idx', 'model.layers.13.mlp.up_proj.qzeros', 'model.layers.13.self_attn.q_proj.bias', 'model.layers.15.mlp.up_proj.g_idx', 'model.layers.12.self_attn.k_proj.qweight', 'model.layers.27.self_attn.o_proj.qweight', 'model.layers.16.self_attn.o_proj.qweight', 'model.layers.19.mlp.gate_proj.g_idx', 'model.layers.31.self_attn.k_proj.scal ...
# - This IS expected if you are initializing LlamaForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LlamaForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of LlamaForCausalLM were not initialized from the model checkpoint at SebastianSchramm/UniNER-7B-all-GPTQ-4bit-128g-actorder_True and are newly initialized: ['model.layers.2.self_attn.o_proj.weight', 'model.layers.7.self_attn.o_proj.weight', 'model.layers.6.mlp.gate_proj.weight', 'model.layers.17.mlp.gate_proj.weight', 'model.layers.21.self_attn.v_proj.weight', 'model.layers.21.self_attn.q_proj.weight', 'model.layers.8.mlp.up_proj.weight', 'model.layers.4.self_attn.o_proj.weight', 'model.layers.24.self_attn.rotary_emb.inv_freq', 'model.layers.0.self_attn.q_proj.weight', 'model.layers.10.self_attn.o_proj.weight', 'model.layers.11.mlp.down_proj.weight', 'model.layers.1.self_attn.k_proj.weight', 'model.layers.17.self_attn.k_proj.weight', 'model.layers.29.self_attn.rotary_emb.inv_freq', 'model.layers.23.self_attn.o_proj.weight', 'model.layers.18.mlp.down_proj.weight', 'model.layers.30.self_attn.o_proj.weight', 'model.layers.14.mlp.up_proj.weight', 'model.layers.26.self_attn.k_proj.weight', 'model.layers.29.mlp.down_proj.weight', 'model.layers.10.mlp.down_proj.weight', 'model.layers.1.self_attn.rotary_emb.inv_freq', 'model.layers.13.mlp.down_proj.weight', 'model.layers.26.self_attn.rotary_emb.inv_freq', 'model.layers.12.self_attn.k_proj.weight', 'model.layers.23.mlp.down_proj.weight', 'model.layers.11.self_attn.q_proj.weight', 'model.layers.11.mlp.gate_proj.weight', 'model.layers.8.self_attn.o_proj.weight', 'model.layers.18.self_attn.rotary_emb.inv_freq', 'model.layers.15.self_attn.o_proj.weight', 'model.layers.11.self_attn.o_proj.weight', 'model.layers.8.self_attn.k_proj.weight', 'model.layers.26.self_attn.q_proj.weight', 'model.layers.25.mlp.down_proj.weight', 'model.layers.14.self_attn.rotary_emb.inv_freq', 'model.layers.30.mlp.down_proj.weight', 'model.layers.5.self_attn.o_proj.weight', 'model.layers.20.mlp.down_proj.weight', 'model.layers.31.self_attn.rotary_emb.inv_freq', 'model.layers.2.self_attn.q_proj.weight', 'model.layers.9.self_attn.o_proj.weight', 'model.layers.12.self_attn.o_proj.weight', 'model.layers.24.self_attn.k_proj.weight', 'model.layers.17.mlp.up_proj.weight', 'model.layers.21.mlp.gate_proj.weight', 'model.layers.3.mlp.gate_proj.weight', 'model.layers.25.self_attn.rotary_emb.inv_freq', 'model.layers.26.self_attn.v_proj.weight', 'model.layers.16.self_attn.rotary_emb.inv_freq', 'model.layers.3.self_attn.v_proj.weight', 'model.layers.13.mlp.up_proj.weight', 'model.layers.31.mlp.up_proj.weight', 'model.layers.28.mlp.up_proj.weight', 'model.layers.0.self_attn.rotary_emb.inv_freq', 'model.layers.24.mlp.up_proj.weight', 'model.layers.7.mlp.gate_proj.weight', 'model.layers.18.self_attn.k_proj.weight', 'model.layers.10.self_attn.rotary_emb.inv_freq', 'model.layers.3.self_attn.k_proj.weight', 'model.layers.9.self_attn.rotary_emb.inv_freq', 'model.layers.27.mlp.up_proj.weight', 'model.layers.1.self_attn.o_proj.weight', 'model.layers.31.self_attn.v_proj.weight', 'model.layers.22.self_attn.k_proj.weight', 'model.layers.23.self_attn.rotary_emb.inv_freq', 'model.layers.5.self_attn.v_proj.weight', 'model.layers.17.mlp.down_proj.weight', 'model.layers.1.mlp.down_proj.weight', 'model.layers.5.mlp.up_proj.weight', 'model.layers.10.self_attn.v_proj.weight', 'model.layers.6.self_attn.k_proj.weight', 'model.layers.13.self_attn.q_proj.weight', 'model.layers.15.mlp.down_proj.weight', 'model.layers.16.self_attn.k_proj.weight', 'model.layers.15.self_attn.v_proj.weight', 'model.layers.22.self_attn.o_proj.weight', 'model.layers.13.mlp.gate_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.21.self_attn.k_proj.weight', 'model.layers.13.self_attn.rotary_emb.inv_freq', 'model.layers.21.mlp.up_proj.weight', 'model.layers.20.self_attn.v_proj.weight', 'model.layers.7.self_attn.q_proj.weight', 'model.layers.10.mlp.gate_proj.weight', 'model.layers.19.self_attn.k_proj.weight', 'model.layers.18.self_attn.q_proj.weight', 'model.layers.15.self_attn.rotary_emb.inv_freq', 'model.layers.17.self_attn.rotary_emb.inv_freq', ' ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import json 

with open('../data/llm_dataset.json') as f:
    data = json.load(f)

prompt_template = """A virtual assistant answers questions from a user based on the provided text.
USER: Text: {input_text}
ASSISTANT: I’ve read this text.
USER: What describes {entity_name} in the text?
ASSISTANT: (model's predictions in JSON format)
"""

patient_nums = [0, 15, 30, 78, 165, 276, 345, 428, 567, 735, 852, 961]
patient_num = patient_nums[2]
text = data[patient_num].strip()
entity = "date of birth"

prompt = prompt_template.format_map({"input_text": text, "entity_name": entity})

def generate_text(prompt):
    input_ids = tokenizer.encode(prompt, return_tensors='pt')
    outputs = model.generate(input_ids, max_length=100)
    generated_text = tokenizer.decode(outputs[0])
    return generated_text

output = generate_text(prompt)
print(output)
# Out:
# /Users/scarlettkynoch/miniconda3/envs/privacyfp/lib/python3.8/site-packages/transformers/generation/utils.py:1259: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# Input length of input_ids is 394, but `max_length` is set to 100. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# <s> A virtual assistant answers questions from a user based on the provided text.
# USER: Text: Mr. Mauro Paucek is a 34 year old male with an NHS number 183 236 1107, born on 1982-03-07. He is of mixed ethnicity, white and Asian, married, and living at 257 McLaughlin Lane Apt 92, Basingstoke, RG21 1ZB. He visited Basingstoke and North Hampshire Hospital on 2016-09-09 with a primary reason of viral sinusitis. The doctor attending was Dylan Robel.
# Observations were taken at the visit, including body height (170.0 cm), pain severity (2.0 {score}), body weight (83.0 kg), body mass index (28.7 kg/m2), diastolic blood pressure (55.0 mm[Hg]), systolic blood pressure (114.0 mm[Hg]), heart rate (85.0 /min) and respiratory rate (12.0 /min). Tobacco smoking status was recorded as Ex-smoker (finding).
# Prescriptions included Hydrochlorothiazide 25 MG Oral Tablet, lisinopril 10 MG Oral Tablet, and amLODIPine 2.5 MG Oral Tablet. Procedures included Assessment of health and social care needs and Med
# ASSISTANT: I’ve read this text.
# USER: What describes date of birth in the text?
# ASSISTANT: (model's predictions in JSON format)
# Infl

# %%
print(output)
# Out:
# <s> A virtual assistant answers questions from a user based on the provided text.
# USER: Text: Mr. Mauro Paucek is a 34 year old male with an NHS number 183 236 1107, born on 1982-03-07. He is of mixed ethnicity, white and Asian, married, and living at 257 McLaughlin Lane Apt 92, Basingstoke, RG21 1ZB. He visited Basingstoke and North Hampshire Hospital on 2016-09-09 with a primary reason of viral sinusitis. The doctor attending was Dylan Robel.
# Observations were taken at the visit, including body height (170.0 cm), pain severity (2.0 {score}), body weight (83.0 kg), body mass index (28.7 kg/m2), diastolic blood pressure (55.0 mm[Hg]), systolic blood pressure (114.0 mm[Hg]), heart rate (85.0 /min) and respiratory rate (12.0 /min). Tobacco smoking status was recorded as Ex-smoker (finding).
# Prescriptions included Hydrochlorothiazide 25 MG Oral Tablet, lisinopril 10 MG Oral Tablet, and amLODIPine 2.5 MG Oral Tablet. Procedures included Assessment of health and social care needs and Med
# ASSISTANT: I’ve read this text.
# USER: What describes date of birth in the text?
# ASSISTANT: (model's predictions in JSON format)
# Infl
