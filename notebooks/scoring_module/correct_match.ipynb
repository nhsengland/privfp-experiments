# %%
import julia
from julia.api import Julia

# %%
julia.install(julia="/Users/scarlettkynoch/Documents/julia-1.10.0/bin/julia")
Julia(compiled_modules=False, runtime="/Users/scarlettkynoch/Documents/julia-1.10.0/bin/julia")
import correctmatch
# Out:
# [ Info: Julia version info
# Julia Version 1.10.0
# Commit 3120989f39b (2023-12-25 18:01 UTC)
# Build Info:
#   Official https://julialang.org/ release
# Platform Info:
#   OS: macOS (x86_64-apple-darwin22.4.0)
#   uname: Darwin 23.1.0 Darwin Kernel Version 23.1.0: Mon Oct  9 21:28:12 PDT 2023; root:xnu-10002.41.9~6/RELEASE_ARM64_T8103 x86_64 i386
#   CPU: Apple M1:
#               speed         user         nice          sys         idle          irq
#        #1  2400 MHz    1297955 s          0 s     864344 s    7543684 s          0 s
#        #2  2400 MHz    1210142 s          0 s     832314 s    7731935 s          0 s
#        #3  2400 MHz    1046144 s          0 s     704241 s    8063693 s          0 s
#        #4  2400 MHz     926031 s          0 s     600217 s    8317831 s          0 s
#        #5  2400 MHz     990789 s          0 s     217298 s    8723885 s          0 s
#        #6  2400 MHz     838183 s          0 s     138002 s    8970301 s          0 s
# ...
